# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('train.csv')
none_not_accepted = ['id', 'Aerial Duels won', 'Age', 'Assists',
       'Attacking options created', 'Attempted Passes', 'Blocks', 'Clearances',
       'Country_val', 'Expected Goal Contributions', 'Interceptions',
       'Open Play Goals', 'Open Play Expected Goals',
       'Percentage of Passes Completed', 'Progressive Passes Rec',
       'Progressive Passes', 'Progressive Carries', 'Shots',
       'Successful Dribbles', 'Touches in attacking penalty area', 'Tackles',
       'Value at beginning of 2020/21 season',
       'Value at beginning of 2021/22 season',
       'Value at beginning of 2022/23 season']
for column in none_not_accepted:
    mn = int(dataset[column].mean(skipna=True))
    dataset[column] = dataset[column].replace(np.NaN,mn)

# %%
plt.figure(figsize=(24,24))
sns.heatmap(dataset.corr(),annot=True)
# Out:
# C:\Users\deban\AppData\Local\Temp\ipykernel_15500\3948777643.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(dataset.corr(),annot=True)
# <Axes: >

# %% [markdown]
# ### PLOTTING TO BETTER UNDERSTAND DATASET

# %%
plt.scatter(dataset['Value at beginning of 2022/23 season'], dataset['Value at beginning of 2023/24 season'],alpha = 0.5)
plt.title('Scatter Plot with Value of 2022/23 Season')
plt.xlabel("Value of 2022/23 season")
plt.ylabel("Value of 2023/24 season")
plt.show()

# %%
plt.scatter(dataset['Value at beginning of 2021/22 season'], dataset['Value at beginning of 2023/24 season'],alpha = 0.5)
plt.title('Scatter Plot with Value of 2021/22 Season')
plt.xlabel("Value of 2021/22 season")
plt.ylabel("Value of 2023/24 season")
plt.show()

# %%
plt.scatter(dataset['Value at beginning of 2020/21 season'], dataset['Value at beginning of 2023/24 season'],alpha = 0.5)
plt.title('Scatter Plot with Value of 2020/21 Season')
plt.xlabel("Value of 2020/21 season")
plt.ylabel("Value of 2023/24 season")
plt.show()

# %%
plt.scatter(dataset['Tackles'], dataset['Value at beginning of 2023/24 season'],alpha = 0.5)
plt.title('Scatter Plot with Tackles')
plt.xlabel("Tackles")
plt.ylabel("Value of 2023/24 season")
plt.show()

# %%
plt.scatter(dataset['Touches in attacking penalty area'], dataset['Value at beginning of 2023/24 season'],alpha = 0.5)
plt.title('Scatter Plot with Touches in penalty')
plt.xlabel("Touches in attacking penalty area")
plt.ylabel("Value of 2023/24 season")
plt.show()

# %%
plt.scatter(dataset['Successful Dribbles'], dataset['Value at beginning of 2023/24 season'],alpha = 0.5)
plt.title('Scatter Plot with Successful Dribbles')
plt.xlabel("Successful Dribbles")
plt.ylabel("Value of 2023/24 season")
plt.show()

# %%
plt.scatter(dataset['Shots'], dataset['Value at beginning of 2023/24 season'],alpha = 0.5)
plt.title('Scatter Plot with Shots')
plt.xlabel("Shots")
plt.ylabel("Value of 2023/24 season")
plt.show()

# %%
plt.scatter(dataset['Progressive Carries'], dataset['Value at beginning of 2023/24 season'],alpha = 0.5)
plt.title('Scatter Plot with Progressive Carries')
plt.xlabel("Progressive Carries")
plt.ylabel("Value of 2023/24 season")
plt.show()

# %%
plt.scatter(dataset['Progressive Passes'], dataset['Value at beginning of 2023/24 season'],alpha = 0.5)
plt.title('Scatter Plot with Progressive Passes')
plt.xlabel("Progressive Passes")
plt.ylabel("Value of 2023/24 season")
plt.show()

# %%
plt.scatter(dataset['Progressive Passes Rec'], dataset['Value at beginning of 2023/24 season'],alpha = 0.5)
plt.title('Scatter Plot with Progressive Passes Rec')
plt.xlabel("Progressive Passes Rec")
plt.ylabel("Value of 2023/24 season")
plt.show()

# %%
plt.scatter(dataset['Percentage of Passes Completed'], dataset['Value at beginning of 2023/24 season'],alpha = 0.5)
plt.title('Scatter Plot with Percentage of Passes Completed')
plt.xlabel("Percentage of Passes Completed")
plt.ylabel("Value of 2023/24 season")
plt.show()

# %%
plt.scatter(dataset['Open Play Expected Goals'], dataset['Value at beginning of 2023/24 season'],alpha = 0.5)
plt.title('Scatter Plot with Open Play Expected Goals')
plt.xlabel("Open Play Expected Goals")
plt.ylabel("Value of 2023/24 season")
plt.show()

# %%
plt.scatter(dataset['Open Play Goals'], dataset['Value at beginning of 2023/24 season'],alpha = 0.5)
plt.title('Scatter Plot with Open Play Goals')
plt.xlabel("Open Play Goals")
plt.ylabel("Value of 2023/24 season")
plt.show()

# %%
plt.scatter(dataset['Interceptions'], dataset['Value at beginning of 2023/24 season'],alpha = 0.5)
plt.title('Scatter Plot with Interceptions')
plt.xlabel("Interceptions")
plt.ylabel("Value of 2023/24 season")
plt.show()

# %%
print(dataset.columns)
# Out:
# Index(['id', 'Name', 'Aerial Duels won', 'Age', 'Assists',
#        'Attacking options created', 'Attempted Passes', 'Blocks', 'Clearances',
#        'Country_val', 'Expected Goal Contributions', 'Interceptions',
#        'Open Play Goals', 'Open Play Expected Goals',
#        'Percentage of Passes Completed', 'Progressive Passes Rec',
#        'Progressive Passes', 'Progressive Carries', 'Shots',
#        'Successful Dribbles', 'Touches in attacking penalty area', 'Tackles',
#        'Value at beginning of 2020/21 season',
#        'Value at beginning of 2021/22 season',
#        'Value at beginning of 2022/23 season',
#        'Value at beginning of 2023/24 season'],
#       dtype='object')

# %%
collist = ['Aerial Duels won', 'Age', 'Assists', 'Attacking options created',
       'Attempted Passes', 'Blocks', 'Clearances',
       'Expected Goal Contributions', 'Interceptions', 'Open Play Goals',
       'Open Play Expected Goals', 'Percentage of Passes Completed',
       'Progressive Passes Rec', 'Progressive Passes', 'Progressive Carries',
       'Shots', 'Successful Dribbles', 'Touches in attacking penalty area',
       'Tackles', 'Value at beginning of 2020/21 season',
       'Value at beginning of 2021/22 season',
       'Value at beginning of 2022/23 season']

# %%
for colpos in range(0,len(collist)):
  
  plt.subplot(8,6,colpos+1)
  X= dataset['Value at beginning of 2023/24 season']
  Y=dataset[collist[colpos]]
  plt.plot(X,Y,label=collist[colpos])
  plt.legend()

# %%
dataset
dataset.drop(columns = ['Name'],axis = 1)
# Out:
#         id  Aerial Duels won  Age  Assists  Attacking options created  \
# 0      917               1.3   23     0.11                       3.68
# 1      432               0.2   21     0.17                       3.49
# 2      948               0.0   24     0.28                       2.99
# 3      989               2.1   25     0.24                       2.44
# 4      887               2.9   26     0.05                       1.19
# ...    ...               ...  ...      ...                        ...
# 1288  1130               0.5   28     0.26                       3.41
# 1289  1294               0.3   31     0.00                       4.01
# 1290   860               0.7   24     0.04                       2.61
# 1291  1459               0.4   23     0.03                       1.63
# 1292  1126               0.4   31     0.14                       2.15
#
#       Attempted Passes  Blocks  Clearances  Country_val  \
# 0                 31.8    0.69        0.97           50
# ...

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %%
dependent_list = "Value at beginning of 2023/24 season"

# %%
independent_list = dataset.columns.tolist()
independent_list.remove(dependent_list)

# %%
dependent_list
# Out:
# 'Value at beginning of 2023/24 season'

# %%
independent_list.remove("Name")
independent_list
# Out:
# ['id',
#  'Aerial Duels won',
#  'Age',
#  'Assists',
#  'Attacking options created',
#  'Attempted Passes',
#  'Blocks',
#  'Clearances',
#  'Country_val',
#  'Expected Goal Contributions',
#  'Interceptions',
#  'Open Play Goals',
#  'Open Play Expected Goals',
#  'Percentage of Passes Completed',
#  'Progressive Passes Rec',
#  'Progressive Passes',
#  'Progressive Carries',
#  'Shots',
#  'Successful Dribbles',
#  'Touches in attacking penalty area',
#  'Tackles',
#  'Value at beginning of 2020/21 season',
#  'Value at beginning of 2021/22 season',
#  'Value at beginning of 2022/23 season']

# %%
X = dataset[independent_list].values

y = dataset[dependent_list].values

# %%
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size = 0.25, random_state = True)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
import math
math.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 10.275856196454452

# %%
r2_score(y_test,y_pred)
# Out:
# 0.780976177916115

# %%
test_df = pd.read_csv('test.csv')
none_not_accepted = ['id', 'Aerial Duels won', 'Age', 'Assists',
       'Attacking options created', 'Attempted Passes', 'Blocks', 'Clearances',
       'Country_val', 'Expected Goal Contributions', 'Interceptions',
       'Open Play Goals', 'Open Play Expected Goals',
       'Percentage of Passes Completed', 'Progressive Passes Rec',
       'Progressive Passes', 'Progressive Carries', 'Shots',
       'Successful Dribbles', 'Touches in attacking penalty area', 'Tackles',
       'Value at beginning of 2020/21 season',
       'Value at beginning of 2021/22 season',
       'Value at beginning of 2022/23 season']
for column in none_not_accepted:
    mn = int(dataset[column].mean(skipna=True))
    test_df[column] = test_df[column].replace(np.NaN,mn)

# %%
X_tests = test_df[independent_list].values
y_tests = []

# %%
X_tests = scaler.fit_transform(X_tests)

# %%
y_tests = model.predict(X_tests)

# %%
y_tests
# Out:
# array([ 4.03321852e+00,  1.12031982e+01,  7.20346039e+00,  1.05385280e+01,
#         3.77740842e+00,  2.38281868e+01,  1.17884839e+01,  4.32863893e+00,
#         5.54176228e+01,  1.50291502e+01,  1.55694004e+01,  3.27156084e+00,
#         3.31691987e+00,  1.86974193e+01,  5.74749678e+00,  4.92898197e+01,
#         3.38648289e+00,  1.31130751e+01,  2.19105142e+00,  6.16365734e+00,
#         6.08895958e+01,  8.42236397e+00,  6.33023501e+00,  4.63166110e+01,
#         1.51226894e+00, -4.40423772e+00,  1.30047377e+01,  5.18963883e+01,
#         3.88359435e+00,  1.33953329e+01,  1.81055258e+00,  5.71297767e+00,
#         8.41438181e+00,  4.14907385e+00,  7.36851122e+00,  4.10123334e+00,
#        -7.85034810e-01,  1.51796396e+01,  2.57674461e+01,  2.07248863e+01,
#         5.82159793e+01,  1.05271119e+01,  1.48766463e+01,  1.87361893e+01,
#         7.14752516e-01,  2.90137782e+00,  2.26613739e+01,  3.33658491e+01,
# ...

# %%
test_df['label'] = y_tests

# %%
test_df.drop(columns = ['Aerial Duels won', 'Age', 'Assists', 'Attacking options created',
       'Attempted Passes', 'Blocks', 'Clearances',
       'Expected Goal Contributions', 'Interceptions', 'Open Play Goals',
       'Open Play Expected Goals', 'Percentage of Passes Completed',
       'Progressive Passes Rec', 'Progressive Passes', 'Progressive Carries',
       'Shots', 'Successful Dribbles', 'Touches in attacking penalty area',
       'Tackles', 'Value at beginning of 2020/21 season',
       'Value at beginning of 2021/22 season',
       'Value at beginning of 2022/23 season','Country_val'],axis = 1)
# Out:
#        id      label
# 0     705   4.033219
# 1     809  11.203198
# 2    1432   7.203460
# 3     173  10.538528
# 4     513   3.777408
# ..    ...        ...
# 404  1220  -2.887432
# 405   478   3.243948
# 406   798   5.452354
# 407  1563   1.298297
# 408  1667  14.667580
#
# [409 rows x 2 columns]

# %%
test_df.to_csv('submission4.csv', index = False)
